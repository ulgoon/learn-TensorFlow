# %% [markdown]
# # Basic Concepts of Machine Learning
#
# - What is ML?
# - What is learning?
# 	- supervised
# 	- unsupervised
# - What is regression?
# - What is classification?
#
# #### Machine Learning
# - Limitations of explicit programming
# 	- Spam filter: many rules
# 	- Automatic driving: too many rules
# - Machine learning: "Field of study that gives computers the ability to learn without being explicitly programmed” Arthur Samuel (1959)
#
# #### Supervised / Unsupervised learning
# - Supervised learning:
# 	- learning with labeled examples: training set
# `트레이닝 셋을 활용하여 학습을 하는 방법`
#
# An example training set for four visual categories.
# - cat, dog, mug, hat
#
# - Unsupervised learning: un-labeled data
# 	- Google news grouping
# 	- Word clustering
# `스스로 학습하는 방법`
#
# #### Supervised learning
# - Most common problem type in ML
# 	- Image labeling: learning from tagged images
# 	- Email spam filter: learning from labeled (spam or ham) email
# 	- Predicting exam score: learning from previous exam score and time spent
#
# #### Training data set
# - Feature(X) Labeled data set(Y) --> ML(학습)
# - 이 모델을 통해 X_test 를 주입하여 Training data set과 가장 유사한 Y를 출력
#
#
# #### AlphaGo
# - 이전까지의 기보를 학습
# - 특정한 기사 혹은 그 위치에 놓였을 때의 가장 많이 두는 수를 출력
#
#
# #### Types of supervised learning
# - Predicting final exam score based on time spent
# 	- regression
# 	- `넓은 범위의 값을 예측하는 것`
# - Pass/non-pass based on time spent
# 	- binary classification
# 	- `둘 중 하나를 분류하는 것`
# - Letter grade (A, B, C, E and F) based on time spent
# 	- multi-label classification
# 	- `여러 등급 중 하나로 분류하는 것`
#
# #### Predicting final exam score based on time spent
#
# |x(hours)|y(score)|
# |:--:|:--:|
# |10|90|
# |9|80|
# |3|50|
# |2|30|
#
# - `위의 시험 데이터를 Regression 모델에 학습을 시킴`
# - `x=7일 경우 75점을 예측값으로 반환할 것`
#
# #### Pass/non-pass based on time spent
#
# |x(hours)|y(P/F)|
# |:--:|:--:|
# |10|P|
# |9|P|
# |3|F|
# |2|F|
#
# #### Letter grade (A, B, …) based on time spent
#
# |x(hours)|y(grade)|
# |:--:|:--:|
# |10|A|
# |9|B|
# |3|D|
# |2|F|
